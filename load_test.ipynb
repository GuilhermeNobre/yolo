# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2
from IPython.display import Image

# %%
model = YOLO("cat_dog_model.pt")

# %%
results = model('test/14.jpg')
results_image = results[0].plot()
result_image_rgb = cv2.cvtColor(results_image, cv2.COLOR_BGR2RGB)
output_path = 'output2.jpg'
cv2.imwrite(output_path, results_image)
Image(output_path)
# Out:
# image 1/1 /home/guilherme/Work/Python/yolo/test/14.jpg: 480x640 1 cachorro, 1 gato, 57.8ms
# Speed: 1.6ms preprocess, 57.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
